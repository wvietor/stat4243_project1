# %%
import anndata
import scanpy as sc

# %% [markdown]
# # Read the cleaned data and normalize by count

# %%
ad = anndata.read_h5ad('cleaned_processed_frogtail.h5ad')
sc.pp.normalize_total(ad, target_sum=1e4)
sc.pp.neighbors(ad, metric='cosine')
# Out:
# /opt/miniconda3/envs/stat4243/lib/python3.11/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /opt/miniconda3/envs/stat4243/lib/python3.11/site-packages/scanpy/tools/_utils.py:41: UserWarning: You’re trying to run this on 31535 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
#   warnings.warn(

# %% [markdown]
# # Exploratory Analysis

# %% [markdown]
# ## Cluster-Wise Correlation Matrix

# %%
sc.pl.correlation_matrix(ad, 'cluster')
# Out:
# WARNING: dendrogram data not found (using key=dendrogram_cluster). Running `sc.tl.dendrogram` with default parameters. For fine tuning it is recommended to run `sc.tl.dendrogram` independently.

# %% [markdown]
# It's clear that the erythrocyte cells are quite distinct from all the others but similar to each other.

# %% [markdown]
# ## UMAP (cosine distance)

# %%
sc.tl.umap(ad)
sc.pl.umap(ad, color='cluster')

# %% [markdown]
# ## t-SNE (cosine distance)

# %%
sc.tl.tsne(ad)
sc.pl.tsne(ad, color='cluster')

# %%
sc.tl.rank_genes_groups(ad, groupby='cluster', method='logreg')
sc.pl.rank_genes_groups_heatmap(ad, n_genes=15, groupby='cluster')

# %%
ad.obs_keys()
